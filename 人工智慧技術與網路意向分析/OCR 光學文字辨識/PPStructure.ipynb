# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd '/content/drive/MyDrive/Colab Notebooks/人工智慧技術與網路意向分析/Week 12 OCR Technique/testdata'
# Out:
# /content/drive/MyDrive/Colab Notebooks/人工智慧技術與網路意向分析/Week 12 OCR Technique/testdata

# %%
! pip install paddleocr
# !pip install paddlepaddle
# !pip install Polygon3
# !pip install lanms
# !git clone https://github.com/PaddlePaddle/PaddleOCR
# Out:
# ...
# fatal: destination path 'PaddleOCR' already exists and is not an empty directory.

# %%
# ! pip install  "paddleocr>=2.2"  # 推薦使用2.2+版本
! python -m pip install --force-reinstall paddlepaddle==2.5
# Out:
# ...
#   Using cached paddlepaddle-2.5.0-cp310-cp310-manylinux1_x86_64.whl (124.9 MB)
# ...
#   Using cached httpx-0.24.1-py3-none-any.whl (75 kB)
# ...
#   Using cached numpy-1.25.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.2 MB)
# ...
#   Using cached Pillow-10.0.0-cp310-cp310-manylinux_2_28_x86_64.whl (3.4 MB)
# ...
#   Using cached decorator-5.1.1-py3-none-any.whl (9.1 kB)
# ...
#   Using cached astor-0.8.1-py2.py3-none-any.whl (27 kB)
# ...
#   Using cached paddle_bfloat-0.1.7-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (383 kB)
# ...
#   Using cached opt_einsum-3.3.0-py3-none-any.whl (65 kB)
# ...
#   Using cached protobuf-4.24.0-cp37-abi3-manylinux2014_x86_64.whl (311 kB)
# ...
#   Using cached certifi-2023.7.22-py3-none-any.whl (158 kB)
# ...
#   Using cached httpcore-0.17.3-py3-none-any.whl (74 kB)
# ...
#   Using cached idna-3.4-py3-none-any.whl (61 kB)
# ...
#   Using cached sniffio-1.3.0-py3-none-any.whl (10 kB)
# ...
#   Using cached h11-0.14.0-py3-none-any.whl (58 kB)
# ...

# %%
! pip install --force-reinstall paddlepaddle==2.5
# Out:
# ...
#   Using cached paddlepaddle-2.5.0-cp310-cp310-manylinux1_x86_64.whl (124.9 MB)
# ...
#   Using cached httpx-0.24.1-py3-none-any.whl (75 kB)
# ...
#   Using cached numpy-1.25.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.2 MB)
# ...
#   Using cached Pillow-10.0.0-cp310-cp310-manylinux_2_28_x86_64.whl (3.4 MB)
# ...
#   Using cached decorator-5.1.1-py3-none-any.whl (9.1 kB)
# ...
#   Using cached astor-0.8.1-py2.py3-none-any.whl (27 kB)
# ...
#   Using cached paddle_bfloat-0.1.7-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (383 kB)
# ...
#   Using cached opt_einsum-3.3.0-py3-none-any.whl (65 kB)
# ...
#   Using cached protobuf-4.24.0-cp37-abi3-manylinux2014_x86_64.whl (311 kB)
# ...
#   Using cached certifi-2023.7.22-py3-none-any.whl (158 kB)
# ...
#   Using cached httpcore-0.17.3-py3-none-any.whl (74 kB)
# ...
#   Using cached idna-3.4-py3-none-any.whl (61 kB)
# ...
#   Using cached sniffio-1.3.0-py3-none-any.whl (10 kB)
# ...
#   Using cached h11-0.14.0-py3-none-any.whl (58 kB)
# ...

# %%
from paddleocr import PaddleOCR,draw_ocr
import logging

root_logger= logging.getLogger() # 追蹤路徑
root_logger.setLevel(logging.INFO) # or whatever
handler = logging.FileHandler('test_example_1.log', 'w', 'utf-8') # or whatever
handler.setFormatter(logging.Formatter('%(name)s %(message)s')) # or whatever
root_logger.addHandler(handler)
# Out:
# Error: Can not import paddle core while this file exists: /usr/local/lib/python3.10/dist-packages/paddle/fluid/libpaddle.so
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-9-70da5f0ffd09> in <cell line: 1>()
# ----> 1 from paddleocr import PaddleOCR,draw_ocr
#       2 import logging
#       3
#       4 root_logger= logging.getLogger() # 追蹤路徑
#       5 root_logger.setLevel(logging.INFO) # or whatever
#
# /usr/local/lib/python3.10/dist-packages/paddleocr/__init__.py in <module>
#      12 # See the License for the specific language governing permissions and
#      13 # limitations under the License.
# ---> 14 from .paddleocr import *
#      15
#      16 __version__ = paddleocr.VERSION
#
# /usr/local/lib/python3.10/dist-packages/paddleocr/paddleocr.py in <module>
#      19 __dir__ = os.path.dirname(__file__)
#      20
# ---> 21 import paddle
#      22
# ...

# %%
import  os
import  cv2
from  paddleocr  import  PPStructure , draw_structure_result , save_structure_res

table_engine  =  PPStructure ( show_log = True )

save_folder  = '/content/drive/MyDrive/Colab Notebooks/人工智慧技術與網路意向分析/Week 12 OCR Technique/Result folder'
img_path  =  '/content/drive/MyDrive/Colab Notebooks/人工智慧技術與網路意向分析/Week 12 OCR Technique/testdata/meme_2.jpg'
img  =  cv2 . imread ( img_path )
result  =  table_engine ( img )
save_structure_res ( result ,  save_folder , os . path . basename ( img_path ). split ( '.' )[ 0 ])

for  line  in  result :
  line.pop ( 'img' )
  print ( line )


from  PIL  import  Image

font_path  = r'/content/drive/MyDrive/Colab Notebooks/人工智慧技術與網路意向分析/Week 12 OCR Technique/fonts/KAIU.TTF'  # PaddleOCR下提供字體包
image  =  Image . open ( img_path ). convert ( 'RGB' )
im_show  =  draw_structure_result ( image ,  result , font_path = font_path )
im_show  =  Image . fromarray ( im_show )
im_show . save ( 'result.jpg' )
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-5652796676c7> in <cell line: 3>()
#       1 import  os
#       2 import  cv2
# ----> 3 from  paddleocr  import  PPStructure , draw_structure_result , save_structure_res
#       4
#       5 table_engine  =  PPStructure ( show_log = True )
#
# ModuleNotFoundError: No module named 'paddleocr'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
import paddle
import paddleocr
# 加载模型
model = paddleocr.load_model('models/ch_ppocr_mobile_v2.0_det_inference.pdmodel', 'models/ch_ppocr_mobile_v2.0_det_inference.pdiparams')
# 读取图片
img = paddle.vision.io.read_image('test.jpg')
# 检测文字
result = model.predict(img)
# 绘制文字框
for box in result:
    paddle.vision.draw.draw_bounding_box(img, box, color=(0, 255, 0), thickness=2)
# 显示图片
paddle.vision.utils.save_image(img, 'result.jpg')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-ddf331ed6fac> in <cell line: 1>()
# ----> 1 import paddle
#       2 import paddleocr
#       3 # 加载模型
#       4 model = paddleocr.load_model('models/ch_ppocr_mobile_v2.0_det_inference.pdmodel', 'models/ch_ppocr_mobile_v2.0_det_inference.pdiparams')
#       5 # 读取图片
#
# ModuleNotFoundError: No module named 'paddle'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------
