# %% [markdown]
# # 第四週範例程式 -- 使用 nltk 處理英文

# %% [markdown]
# 新聞來源：https://edition.cnn.com/2023/03/05/asia/ukraine-war-us-pacific-alliances-intl-hnk/index.html

# %%
Title_CNN = 'Ukraine war has made it easier for US to isolate China in the Pacific'
Content_CNN = '''A year after Russia invaded Ukraine, Xi Jinping’s backing of Vladimir Putin has opened the door for the United States and partners in the Pacific to shore up sometimes frayed relationships to the detriment of Beijing.

In the past few months alone, Japan has pledged to double defense spending and acquire long-range weapons from the US; South Korea has acknowledged that stability in the Taiwan Strait is essential to its security; the Philippines has announced new US base access rights and is talking about joint patrols of the South China Sea with Australia, Japan and the United States.

Those might be the biggest initiatives, but they are far from the only events that have left China increasingly isolated in its own backyard as it refuses to condemn the invasion of a sovereign country by its partner in Moscow while keeping military pressure on the self-ruled island of Taiwan.

Analysts say all these things would have likely happened without the war in Ukraine, but the war, and China’s backing of Russia, has helped grease the skids to get these projects done.

Take the situation of Japan, a country limited in its post-World War II constitution to “self-defense” forces. Now it’s going to buy long-range Tomahawk cruise missiles from the US, weapons that could strike well inside China.

“I myself have a strong sense of urgency that Ukraine today may be East Asia tomorrow,” Japanese Prime Minister Fumio Kishida told a major defense conference in Singapore last summer.

In December, Kishida followed that up with a plan to double Tokyo’s defense spending while acquiring weapons with ranges well outside Japanese territory.
'''

# %%
# 必須先下載模型、語料
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %% [markdown]
# 基本單位：字

# %%
from nltk.tokenize import word_tokenize

word_result = word_tokenize(Content_CNN)

# check result
print(word_result)
# Out:
# ['A', 'year', 'after', 'Russia', 'invaded', 'Ukraine', ',', 'Xi', 'Jinping', '’', 's', 'backing', 'of', 'Vladimir', 'Putin', 'has', 'opened', 'the', 'door', 'for', 'the', 'United', 'States', 'and', 'partners', 'in', 'the', 'Pacific', 'to', 'shore', 'up', 'sometimes', 'frayed', 'relationships', 'to', 'the', 'detriment', 'of', 'Beijing', '.', 'In', 'the', 'past', 'few', 'months', 'alone', ',', 'Japan', 'has', 'pledged', 'to', 'double', 'defense', 'spending', 'and', 'acquire', 'long-range', 'weapons', 'from', 'the', 'US', ';', 'South', 'Korea', 'has', 'acknowledged', 'that', 'stability', 'in', 'the', 'Taiwan', 'Strait', 'is', 'essential', 'to', 'its', 'security', ';', 'the', 'Philippines', 'has', 'announced', 'new', 'US', 'base', 'access', 'rights', 'and', 'is', 'talking', 'about', 'joint', 'patrols', 'of', 'the', 'South', 'China', 'Sea', 'with', 'Australia', ',', 'Japan', 'and', 'the', 'United', 'States', '.', 'Those', 'might', 'be', 'the', 'biggest', 'initiatives', ',', 'but', 'they', 'are', 'far', 'from', 'the', 'only', 'events', 'that', 'have', 'left', 'China', 'increasingly', 'isolated', 'in', 'its', 'own', 'backyard', 'as', 'it', 'refuses', 'to', 'condemn', 'the', 'invasion', 'of', 'a', 'sovereign', 'country', 'by', 'its', 'partner', 'in', 'Moscow', 'while', 'keeping', 'military', 'pressure', 'on', 'the', 'self-ruled', 'island', 'of', 'Taiwan', '.', 'Analysts', 'say', 'all', 'these', 'things', 'would', 'have', 'likely', 'happened', 'without', 'the', 'war', 'in', 'Ukraine', ',', 'but', 'the', 'war', ',', 'and', 'China', '’', 's', 'backing', 'of', 'Russia', ',', 'has', 'helped', 'grease', 'the', 'skids', 'to', 'get', 'these', 'projects', 'done', '.', 'Take', 'the', 'situation', 'of', 'Japan', ',', 'a', 'country', 'limited', 'in', 'its', 'post-World', 'War', 'II', 'constitution', 'to', '“', 'self-defense', '”', 'forces', '.', 'Now', 'it', '’', 's', 'going', 'to', 'buy', 'long-range', 'Tomahawk', 'cruise', 'missiles', 'from', 'the', 'US', ',', 'weapons', 'that', 'could', 'strike', 'well', 'inside', 'China', '.', '“', 'I', 'myself', 'have', 'a', 'strong', 'sense', 'of', 'urgency', 'that', 'Ukraine', 'today', 'may', 'be', 'East', 'Asia', 'tomorrow', ',', '”', 'Japanese', 'Prime', 'Minister', 'Fumio', 'Kishida', 'told', 'a', 'major', 'defense', 'conference', 'in', 'Singapore', 'last', 'summer', '.', 'In', 'December', ',', 'Kishida', 'followed', 'that', 'up', 'with', 'a', 'plan', 'to', 'double', 'Tokyo', '’', 's', 'defense', 'spending', 'while', 'acquiring', 'weapons', 'with', 'ranges', 'well', 'outside', 'Japanese', 'territory', '.']

# %%
freq_word = nltk.FreqDist(word_result)

topk = 20
print(f'排名前 {topk} 名的字頻：', freq_word.most_common(topk))
# Out:
# 排名前 20 名的字頻： [('the', 19), (',', 11), ('to', 9), ('of', 8), ('.', 8), ('in', 7), ('has', 5), ('and', 5), ('that', 5), ('a', 5), ('’', 4), ('s', 4), ('its', 4), ('China', 4), ('Ukraine', 3), ('Japan', 3), ('defense', 3), ('weapons', 3), ('from', 3), ('US', 3)]

# %% [markdown]
# 基本單位：兩個字

# %%
bigrm_result = nltk.bigrams(word_result)
for bi in bigrm_result:
    print(bi)
# Out:
# ('A', 'year')
# ('year', 'after')
# ('after', 'Russia')
# ('Russia', 'invaded')
# ('invaded', 'Ukraine')
# ('Ukraine', ',')
# (',', 'Xi')
# ('Xi', 'Jinping')
# ('Jinping', '’')
# ('’', 's')
# ('s', 'backing')
# ('backing', 'of')
# ('of', 'Vladimir')
# ('Vladimir', 'Putin')
# ('Putin', 'has')
# ('has', 'opened')
# ('opened', 'the')
# ('the', 'door')
# ('door', 'for')
# ('for', 'the')
# ('the', 'United')
# ('United', 'States')
# ('States', 'and')
# ('and', 'partners')
# ('partners', 'in')
# ('in', 'the')
# ('the', 'Pacific')
# ('Pacific', 'to')
# ('to', 'shore')
# ('shore', 'up')
# ('up', 'sometimes')
# ('sometimes', 'frayed')
# ('frayed', 'relationships')
# ('relationships', 'to')
# ('to', 'the')
# ('the', 'detriment')
# ('detriment', 'of')
# ('of', 'Beijing')
# ('Beijing', '.')
# ('.', 'In')
# ('In', 'the')
# ('the', 'past')
# ('past', 'few')
# ('few', 'months')
# ('months', 'alone')
# ('alone', ',')
# (',', 'Japan')
# ('Japan', 'has')
# ('has', 'pledged')
# ('pledged', 'to')
# ('to', 'double')
# ('double', 'defense')
# ('defense', 'spending')
# ('spending', 'and')
# ('and', 'acquire')
# ('acquire', 'long-range')
# ('long-range', 'weapons')
# ('weapons', 'from')
# ('from', 'the')
# ('the', 'US')
# ('US', ';')
# (';', 'South')
# ('South', 'Korea')
# ('Korea', 'has')
# ('has', 'acknowledged')
# ('acknowledged', 'that')
# ('that', 'stability')
# ('stability', 'in')
# ('in', 'the')
# ('the', 'Taiwan')
# ('Taiwan', 'Strait')
# ('Strait', 'is')
# ('is', 'essential')
# ('essential', 'to')
# ('to', 'its')
# ('its', 'security')
# ('security', ';')
# (';', 'the')
# ('the', 'Philippines')
# ('Philippines', 'has')
# ('has', 'announced')
# ('announced', 'new')
# ('new', 'US')
# ('US', 'base')
# ('base', 'access')
# ('access', 'rights')
# ('rights', 'and')
# ('and', 'is')
# ('is', 'talking')
# ('talking', 'about')
# ('about', 'joint')
# ('joint', 'patrols')
# ('patrols', 'of')
# ('of', 'the')
# ('the', 'South')
# ('South', 'China')
# ('China', 'Sea')
# ('Sea', 'with')
# ('with', 'Australia')
# ('Australia', ',')
# (',', 'Japan')
# ('Japan', 'and')
# ('and', 'the')
# ('the', 'United')
# ('United', 'States')
# ('States', '.')
# ('.', 'Those')
# ('Those', 'might')
# ('might', 'be')
# ('be', 'the')
# ('the', 'biggest')
# ('biggest', 'initiatives')
# ('initiatives', ',')
# (',', 'but')
# ('but', 'they')
# ('they', 'are')
# ('are', 'far')
# ('far', 'from')
# ('from', 'the')
# ('the', 'only')
# ('only', 'events')
# ('events', 'that')
# ('that', 'have')
# ('have', 'left')
# ('left', 'China')
# ('China', 'increasingly')
# ('increasingly', 'isolated')
# ('isolated', 'in')
# ('in', 'its')
# ('its', 'own')
# ('own', 'backyard')
# ('backyard', 'as')
# ('as', 'it')
# ('it', 'refuses')
# ('refuses', 'to')
# ('to', 'condemn')
# ('condemn', 'the')
# ('the', 'invasion')
# ('invasion', 'of')
# ('of', 'a')
# ('a', 'sovereign')
# ('sovereign', 'country')
# ('country', 'by')
# ('by', 'its')
# ('its', 'partner')
# ('partner', 'in')
# ('in', 'Moscow')
# ('Moscow', 'while')
# ('while', 'keeping')
# ('keeping', 'military')
# ('military', 'pressure')
# ('pressure', 'on')
# ('on', 'the')
# ('the', 'self-ruled')
# ('self-ruled', 'island')
# ('island', 'of')
# ('of', 'Taiwan')
# ('Taiwan', '.')
# ('.', 'Analysts')
# ('Analysts', 'say')
# ('say', 'all')
# ('all', 'these')
# ('these', 'things')
# ('things', 'would')
# ('would', 'have')
# ('have', 'likely')
# ('likely', 'happened')
# ('happened', 'without')
# ('without', 'the')
# ('the', 'war')
# ('war', 'in')
# ('in', 'Ukraine')
# ('Ukraine', ',')
# (',', 'but')
# ('but', 'the')
# ('the', 'war')
# ('war', ',')
# (',', 'and')
# ('and', 'China')
# ('China', '’')
# ('’', 's')
# ('s', 'backing')
# ('backing', 'of')
# ('of', 'Russia')
# ('Russia', ',')
# (',', 'has')
# ('has', 'helped')
# ('helped', 'grease')
# ('grease', 'the')
# ('the', 'skids')
# ('skids', 'to')
# ('to', 'get')
# ('get', 'these')
# ('these', 'projects')
# ('projects', 'done')
# ('done', '.')
# ('.', 'Take')
# ('Take', 'the')
# ('the', 'situation')
# ('situation', 'of')
# ('of', 'Japan')
# ('Japan', ',')
# (',', 'a')
# ('a', 'country')
# ('country', 'limited')
# ('limited', 'in')
# ('in', 'its')
# ('its', 'post-World')
# ('post-World', 'War')
# ('War', 'II')
# ('II', 'constitution')
# ('constitution', 'to')
# ('to', '“')
# ('“', 'self-defense')
# ('self-defense', '”')
# ('”', 'forces')
# ('forces', '.')
# ('.', 'Now')
# ('Now', 'it')
# ('it', '’')
# ('’', 's')
# ('s', 'going')
# ('going', 'to')
# ('to', 'buy')
# ('buy', 'long-range')
# ('long-range', 'Tomahawk')
# ('Tomahawk', 'cruise')
# ('cruise', 'missiles')
# ('missiles', 'from')
# ('from', 'the')
# ('the', 'US')
# ('US', ',')
# (',', 'weapons')
# ('weapons', 'that')
# ('that', 'could')
# ('could', 'strike')
# ('strike', 'well')
# ('well', 'inside')
# ('inside', 'China')
# ('China', '.')
# ('.', '“')
# ('“', 'I')
# ('I', 'myself')
# ('myself', 'have')
# ('have', 'a')
# ('a', 'strong')
# ('strong', 'sense')
# ('sense', 'of')
# ('of', 'urgency')
# ('urgency', 'that')
# ('that', 'Ukraine')
# ('Ukraine', 'today')
# ('today', 'may')
# ('may', 'be')
# ('be', 'East')
# ('East', 'Asia')
# ('Asia', 'tomorrow')
# ('tomorrow', ',')
# (',', '”')
# ('”', 'Japanese')
# ('Japanese', 'Prime')
# ('Prime', 'Minister')
# ('Minister', 'Fumio')
# ('Fumio', 'Kishida')
# ('Kishida', 'told')
# ('told', 'a')
# ('a', 'major')
# ('major', 'defense')
# ('defense', 'conference')
# ('conference', 'in')
# ('in', 'Singapore')
# ('Singapore', 'last')
# ('last', 'summer')
# ('summer', '.')
# ('.', 'In')
# ('In', 'December')
# ('December', ',')
# (',', 'Kishida')
# ('Kishida', 'followed')
# ('followed', 'that')
# ('that', 'up')
# ('up', 'with')
# ('with', 'a')
# ('a', 'plan')
# ('plan', 'to')
# ('to', 'double')
# ('double', 'Tokyo')
# ('Tokyo', '’')
# ('’', 's')
# ('s', 'defense')
# ('defense', 'spending')
# ('spending', 'while')
# ('while', 'acquiring')
# ('acquiring', 'weapons')
# ('weapons', 'with')
# ('with', 'ranges')
# ('ranges', 'well')
# ('well', 'outside')
# ('outside', 'Japanese')
# ('Japanese', 'territory')
# ('territory', '.')

# %%
# 那三個字？
trigrm_result = nltk.trigrams(word_result)
for tri in trigrm_result:
    print(tri)
# Out:
# ('A', 'year', 'after')
# ('year', 'after', 'Russia')
# ('after', 'Russia', 'invaded')
# ('Russia', 'invaded', 'Ukraine')
# ('invaded', 'Ukraine', ',')
# ('Ukraine', ',', 'Xi')
# (',', 'Xi', 'Jinping')
# ('Xi', 'Jinping', '’')
# ('Jinping', '’', 's')
# ('’', 's', 'backing')
# ('s', 'backing', 'of')
# ('backing', 'of', 'Vladimir')
# ('of', 'Vladimir', 'Putin')
# ('Vladimir', 'Putin', 'has')
# ('Putin', 'has', 'opened')
# ('has', 'opened', 'the')
# ('opened', 'the', 'door')
# ('the', 'door', 'for')
# ('door', 'for', 'the')
# ('for', 'the', 'United')
# ('the', 'United', 'States')
# ('United', 'States', 'and')
# ('States', 'and', 'partners')
# ('and', 'partners', 'in')
# ('partners', 'in', 'the')
# ('in', 'the', 'Pacific')
# ('the', 'Pacific', 'to')
# ('Pacific', 'to', 'shore')
# ('to', 'shore', 'up')
# ('shore', 'up', 'sometimes')
# ('up', 'sometimes', 'frayed')
# ('sometimes', 'frayed', 'relationships')
# ('frayed', 'relationships', 'to')
# ('relationships', 'to', 'the')
# ('to', 'the', 'detriment')
# ('the', 'detriment', 'of')
# ('detriment', 'of', 'Beijing')
# ('of', 'Beijing', '.')
# ('Beijing', '.', 'In')
# ('.', 'In', 'the')
# ('In', 'the', 'past')
# ('the', 'past', 'few')
# ('past', 'few', 'months')
# ('few', 'months', 'alone')
# ('months', 'alone', ',')
# ('alone', ',', 'Japan')
# (',', 'Japan', 'has')
# ('Japan', 'has', 'pledged')
# ('has', 'pledged', 'to')
# ('pledged', 'to', 'double')
# ('to', 'double', 'defense')
# ('double', 'defense', 'spending')
# ('defense', 'spending', 'and')
# ('spending', 'and', 'acquire')
# ('and', 'acquire', 'long-range')
# ('acquire', 'long-range', 'weapons')
# ('long-range', 'weapons', 'from')
# ('weapons', 'from', 'the')
# ('from', 'the', 'US')
# ('the', 'US', ';')
# ('US', ';', 'South')
# (';', 'South', 'Korea')
# ('South', 'Korea', 'has')
# ('Korea', 'has', 'acknowledged')
# ('has', 'acknowledged', 'that')
# ('acknowledged', 'that', 'stability')
# ('that', 'stability', 'in')
# ('stability', 'in', 'the')
# ('in', 'the', 'Taiwan')
# ('the', 'Taiwan', 'Strait')
# ('Taiwan', 'Strait', 'is')
# ('Strait', 'is', 'essential')
# ('is', 'essential', 'to')
# ('essential', 'to', 'its')
# ('to', 'its', 'security')
# ('its', 'security', ';')
# ('security', ';', 'the')
# (';', 'the', 'Philippines')
# ('the', 'Philippines', 'has')
# ('Philippines', 'has', 'announced')
# ('has', 'announced', 'new')
# ('announced', 'new', 'US')
# ('new', 'US', 'base')
# ('US', 'base', 'access')
# ('base', 'access', 'rights')
# ('access', 'rights', 'and')
# ('rights', 'and', 'is')
# ('and', 'is', 'talking')
# ('is', 'talking', 'about')
# ('talking', 'about', 'joint')
# ('about', 'joint', 'patrols')
# ('joint', 'patrols', 'of')
# ('patrols', 'of', 'the')
# ('of', 'the', 'South')
# ('the', 'South', 'China')
# ('South', 'China', 'Sea')
# ('China', 'Sea', 'with')
# ('Sea', 'with', 'Australia')
# ('with', 'Australia', ',')
# ('Australia', ',', 'Japan')
# (',', 'Japan', 'and')
# ('Japan', 'and', 'the')
# ('and', 'the', 'United')
# ('the', 'United', 'States')
# ('United', 'States', '.')
# ('States', '.', 'Those')
# ('.', 'Those', 'might')
# ('Those', 'might', 'be')
# ('might', 'be', 'the')
# ('be', 'the', 'biggest')
# ('the', 'biggest', 'initiatives')
# ('biggest', 'initiatives', ',')
# ('initiatives', ',', 'but')
# (',', 'but', 'they')
# ('but', 'they', 'are')
# ('they', 'are', 'far')
# ('are', 'far', 'from')
# ('far', 'from', 'the')
# ('from', 'the', 'only')
# ('the', 'only', 'events')
# ('only', 'events', 'that')
# ('events', 'that', 'have')
# ('that', 'have', 'left')
# ('have', 'left', 'China')
# ('left', 'China', 'increasingly')
# ('China', 'increasingly', 'isolated')
# ('increasingly', 'isolated', 'in')
# ('isolated', 'in', 'its')
# ('in', 'its', 'own')
# ('its', 'own', 'backyard')
# ('own', 'backyard', 'as')
# ('backyard', 'as', 'it')
# ('as', 'it', 'refuses')
# ('it', 'refuses', 'to')
# ('refuses', 'to', 'condemn')
# ('to', 'condemn', 'the')
# ('condemn', 'the', 'invasion')
# ('the', 'invasion', 'of')
# ('invasion', 'of', 'a')
# ('of', 'a', 'sovereign')
# ('a', 'sovereign', 'country')
# ('sovereign', 'country', 'by')
# ('country', 'by', 'its')
# ('by', 'its', 'partner')
# ('its', 'partner', 'in')
# ('partner', 'in', 'Moscow')
# ('in', 'Moscow', 'while')
# ('Moscow', 'while', 'keeping')
# ('while', 'keeping', 'military')
# ('keeping', 'military', 'pressure')
# ('military', 'pressure', 'on')
# ('pressure', 'on', 'the')
# ('on', 'the', 'self-ruled')
# ('the', 'self-ruled', 'island')
# ('self-ruled', 'island', 'of')
# ('island', 'of', 'Taiwan')
# ('of', 'Taiwan', '.')
# ('Taiwan', '.', 'Analysts')
# ('.', 'Analysts', 'say')
# ('Analysts', 'say', 'all')
# ('say', 'all', 'these')
# ('all', 'these', 'things')
# ('these', 'things', 'would')
# ('things', 'would', 'have')
# ('would', 'have', 'likely')
# ('have', 'likely', 'happened')
# ('likely', 'happened', 'without')
# ('happened', 'without', 'the')
# ('without', 'the', 'war')
# ('the', 'war', 'in')
# ('war', 'in', 'Ukraine')
# ('in', 'Ukraine', ',')
# ('Ukraine', ',', 'but')
# (',', 'but', 'the')
# ('but', 'the', 'war')
# ('the', 'war', ',')
# ('war', ',', 'and')
# (',', 'and', 'China')
# ('and', 'China', '’')
# ('China', '’', 's')
# ('’', 's', 'backing')
# ('s', 'backing', 'of')
# ('backing', 'of', 'Russia')
# ('of', 'Russia', ',')
# ('Russia', ',', 'has')
# (',', 'has', 'helped')
# ('has', 'helped', 'grease')
# ('helped', 'grease', 'the')
# ('grease', 'the', 'skids')
# ('the', 'skids', 'to')
# ('skids', 'to', 'get')
# ('to', 'get', 'these')
# ('get', 'these', 'projects')
# ('these', 'projects', 'done')
# ('projects', 'done', '.')
# ('done', '.', 'Take')
# ('.', 'Take', 'the')
# ('Take', 'the', 'situation')
# ('the', 'situation', 'of')
# ('situation', 'of', 'Japan')
# ('of', 'Japan', ',')
# ('Japan', ',', 'a')
# (',', 'a', 'country')
# ('a', 'country', 'limited')
# ('country', 'limited', 'in')
# ('limited', 'in', 'its')
# ('in', 'its', 'post-World')
# ('its', 'post-World', 'War')
# ('post-World', 'War', 'II')
# ('War', 'II', 'constitution')
# ('II', 'constitution', 'to')
# ('constitution', 'to', '“')
# ('to', '“', 'self-defense')
# ('“', 'self-defense', '”')
# ('self-defense', '”', 'forces')
# ('”', 'forces', '.')
# ('forces', '.', 'Now')
# ('.', 'Now', 'it')
# ('Now', 'it', '’')
# ('it', '’', 's')
# ('’', 's', 'going')
# ('s', 'going', 'to')
# ('going', 'to', 'buy')
# ('to', 'buy', 'long-range')
# ('buy', 'long-range', 'Tomahawk')
# ('long-range', 'Tomahawk', 'cruise')
# ('Tomahawk', 'cruise', 'missiles')
# ('cruise', 'missiles', 'from')
# ('missiles', 'from', 'the')
# ('from', 'the', 'US')
# ('the', 'US', ',')
# ('US', ',', 'weapons')
# (',', 'weapons', 'that')
# ('weapons', 'that', 'could')
# ('that', 'could', 'strike')
# ('could', 'strike', 'well')
# ('strike', 'well', 'inside')
# ('well', 'inside', 'China')
# ('inside', 'China', '.')
# ('China', '.', '“')
# ('.', '“', 'I')
# ('“', 'I', 'myself')
# ('I', 'myself', 'have')
# ('myself', 'have', 'a')
# ('have', 'a', 'strong')
# ('a', 'strong', 'sense')
# ('strong', 'sense', 'of')
# ('sense', 'of', 'urgency')
# ('of', 'urgency', 'that')
# ('urgency', 'that', 'Ukraine')
# ('that', 'Ukraine', 'today')
# ('Ukraine', 'today', 'may')
# ('today', 'may', 'be')
# ('may', 'be', 'East')
# ('be', 'East', 'Asia')
# ('East', 'Asia', 'tomorrow')
# ('Asia', 'tomorrow', ',')
# ('tomorrow', ',', '”')
# (',', '”', 'Japanese')
# ('”', 'Japanese', 'Prime')
# ('Japanese', 'Prime', 'Minister')
# ('Prime', 'Minister', 'Fumio')
# ('Minister', 'Fumio', 'Kishida')
# ('Fumio', 'Kishida', 'told')
# ('Kishida', 'told', 'a')
# ('told', 'a', 'major')
# ('a', 'major', 'defense')
# ('major', 'defense', 'conference')
# ('defense', 'conference', 'in')
# ('conference', 'in', 'Singapore')
# ('in', 'Singapore', 'last')
# ('Singapore', 'last', 'summer')
# ('last', 'summer', '.')
# ('summer', '.', 'In')
# ('.', 'In', 'December')
# ('In', 'December', ',')
# ('December', ',', 'Kishida')
# (',', 'Kishida', 'followed')
# ('Kishida', 'followed', 'that')
# ('followed', 'that', 'up')
# ('that', 'up', 'with')
# ('up', 'with', 'a')
# ('with', 'a', 'plan')
# ('a', 'plan', 'to')
# ('plan', 'to', 'double')
# ('to', 'double', 'Tokyo')
# ('double', 'Tokyo', '’')
# ('Tokyo', '’', 's')
# ('’', 's', 'defense')
# ('s', 'defense', 'spending')
# ('defense', 'spending', 'while')
# ('spending', 'while', 'acquiring')
# ('while', 'acquiring', 'weapons')
# ('acquiring', 'weapons', 'with')
# ('weapons', 'with', 'ranges')
# ('with', 'ranges', 'well')
# ('ranges', 'well', 'outside')
# ('well', 'outside', 'Japanese')
# ('outside', 'Japanese', 'territory')
# ('Japanese', 'territory', '.')

# %%
# 那四個字？
fourgrm_result = nltk.ngrams(word_result, 4)
for fourG in fourgrm_result:
    print(fourG)

# 五以上，同理可證！
# Out:
# ('A', 'year', 'after', 'Russia')
# ('year', 'after', 'Russia', 'invaded')
# ('after', 'Russia', 'invaded', 'Ukraine')
# ('Russia', 'invaded', 'Ukraine', ',')
# ('invaded', 'Ukraine', ',', 'Xi')
# ('Ukraine', ',', 'Xi', 'Jinping')
# (',', 'Xi', 'Jinping', '’')
# ('Xi', 'Jinping', '’', 's')
# ('Jinping', '’', 's', 'backing')
# ('’', 's', 'backing', 'of')
# ('s', 'backing', 'of', 'Vladimir')
# ('backing', 'of', 'Vladimir', 'Putin')
# ('of', 'Vladimir', 'Putin', 'has')
# ('Vladimir', 'Putin', 'has', 'opened')
# ('Putin', 'has', 'opened', 'the')
# ('has', 'opened', 'the', 'door')
# ('opened', 'the', 'door', 'for')
# ('the', 'door', 'for', 'the')
# ('door', 'for', 'the', 'United')
# ('for', 'the', 'United', 'States')
# ('the', 'United', 'States', 'and')
# ('United', 'States', 'and', 'partners')
# ('States', 'and', 'partners', 'in')
# ('and', 'partners', 'in', 'the')
# ('partners', 'in', 'the', 'Pacific')
# ('in', 'the', 'Pacific', 'to')
# ('the', 'Pacific', 'to', 'shore')
# ('Pacific', 'to', 'shore', 'up')
# ('to', 'shore', 'up', 'sometimes')
# ('shore', 'up', 'sometimes', 'frayed')
# ('up', 'sometimes', 'frayed', 'relationships')
# ('sometimes', 'frayed', 'relationships', 'to')
# ('frayed', 'relationships', 'to', 'the')
# ('relationships', 'to', 'the', 'detriment')
# ('to', 'the', 'detriment', 'of')
# ('the', 'detriment', 'of', 'Beijing')
# ('detriment', 'of', 'Beijing', '.')
# ('of', 'Beijing', '.', 'In')
# ('Beijing', '.', 'In', 'the')
# ('.', 'In', 'the', 'past')
# ('In', 'the', 'past', 'few')
# ('the', 'past', 'few', 'months')
# ('past', 'few', 'months', 'alone')
# ('few', 'months', 'alone', ',')
# ('months', 'alone', ',', 'Japan')
# ('alone', ',', 'Japan', 'has')
# (',', 'Japan', 'has', 'pledged')
# ('Japan', 'has', 'pledged', 'to')
# ('has', 'pledged', 'to', 'double')
# ('pledged', 'to', 'double', 'defense')
# ('to', 'double', 'defense', 'spending')
# ('double', 'defense', 'spending', 'and')
# ('defense', 'spending', 'and', 'acquire')
# ('spending', 'and', 'acquire', 'long-range')
# ('and', 'acquire', 'long-range', 'weapons')
# ('acquire', 'long-range', 'weapons', 'from')
# ('long-range', 'weapons', 'from', 'the')
# ('weapons', 'from', 'the', 'US')
# ('from', 'the', 'US', ';')
# ('the', 'US', ';', 'South')
# ('US', ';', 'South', 'Korea')
# (';', 'South', 'Korea', 'has')
# ('South', 'Korea', 'has', 'acknowledged')
# ('Korea', 'has', 'acknowledged', 'that')
# ('has', 'acknowledged', 'that', 'stability')
# ('acknowledged', 'that', 'stability', 'in')
# ('that', 'stability', 'in', 'the')
# ('stability', 'in', 'the', 'Taiwan')
# ('in', 'the', 'Taiwan', 'Strait')
# ('the', 'Taiwan', 'Strait', 'is')
# ('Taiwan', 'Strait', 'is', 'essential')
# ('Strait', 'is', 'essential', 'to')
# ('is', 'essential', 'to', 'its')
# ('essential', 'to', 'its', 'security')
# ('to', 'its', 'security', ';')
# ('its', 'security', ';', 'the')
# ('security', ';', 'the', 'Philippines')
# (';', 'the', 'Philippines', 'has')
# ('the', 'Philippines', 'has', 'announced')
# ('Philippines', 'has', 'announced', 'new')
# ('has', 'announced', 'new', 'US')
# ('announced', 'new', 'US', 'base')
# ('new', 'US', 'base', 'access')
# ('US', 'base', 'access', 'rights')
# ('base', 'access', 'rights', 'and')
# ('access', 'rights', 'and', 'is')
# ('rights', 'and', 'is', 'talking')
# ('and', 'is', 'talking', 'about')
# ('is', 'talking', 'about', 'joint')
# ('talking', 'about', 'joint', 'patrols')
# ('about', 'joint', 'patrols', 'of')
# ('joint', 'patrols', 'of', 'the')
# ('patrols', 'of', 'the', 'South')
# ('of', 'the', 'South', 'China')
# ('the', 'South', 'China', 'Sea')
# ('South', 'China', 'Sea', 'with')
# ('China', 'Sea', 'with', 'Australia')
# ('Sea', 'with', 'Australia', ',')
# ('with', 'Australia', ',', 'Japan')
# ('Australia', ',', 'Japan', 'and')
# (',', 'Japan', 'and', 'the')
# ('Japan', 'and', 'the', 'United')
# ('and', 'the', 'United', 'States')
# ('the', 'United', 'States', '.')
# ('United', 'States', '.', 'Those')
# ('States', '.', 'Those', 'might')
# ('.', 'Those', 'might', 'be')
# ('Those', 'might', 'be', 'the')
# ('might', 'be', 'the', 'biggest')
# ('be', 'the', 'biggest', 'initiatives')
# ('the', 'biggest', 'initiatives', ',')
# ('biggest', 'initiatives', ',', 'but')
# ('initiatives', ',', 'but', 'they')
# (',', 'but', 'they', 'are')
# ('but', 'they', 'are', 'far')
# ('they', 'are', 'far', 'from')
# ('are', 'far', 'from', 'the')
# ('far', 'from', 'the', 'only')
# ('from', 'the', 'only', 'events')
# ('the', 'only', 'events', 'that')
# ('only', 'events', 'that', 'have')
# ('events', 'that', 'have', 'left')
# ('that', 'have', 'left', 'China')
# ('have', 'left', 'China', 'increasingly')
# ('left', 'China', 'increasingly', 'isolated')
# ('China', 'increasingly', 'isolated', 'in')
# ('increasingly', 'isolated', 'in', 'its')
# ('isolated', 'in', 'its', 'own')
# ('in', 'its', 'own', 'backyard')
# ('its', 'own', 'backyard', 'as')
# ('own', 'backyard', 'as', 'it')
# ('backyard', 'as', 'it', 'refuses')
# ('as', 'it', 'refuses', 'to')
# ('it', 'refuses', 'to', 'condemn')
# ('refuses', 'to', 'condemn', 'the')
# ('to', 'condemn', 'the', 'invasion')
# ('condemn', 'the', 'invasion', 'of')
# ('the', 'invasion', 'of', 'a')
# ('invasion', 'of', 'a', 'sovereign')
# ('of', 'a', 'sovereign', 'country')
# ('a', 'sovereign', 'country', 'by')
# ('sovereign', 'country', 'by', 'its')
# ('country', 'by', 'its', 'partner')
# ('by', 'its', 'partner', 'in')
# ('its', 'partner', 'in', 'Moscow')
# ('partner', 'in', 'Moscow', 'while')
# ('in', 'Moscow', 'while', 'keeping')
# ('Moscow', 'while', 'keeping', 'military')
# ('while', 'keeping', 'military', 'pressure')
# ('keeping', 'military', 'pressure', 'on')
# ('military', 'pressure', 'on', 'the')
# ('pressure', 'on', 'the', 'self-ruled')
# ('on', 'the', 'self-ruled', 'island')
# ('the', 'self-ruled', 'island', 'of')
# ('self-ruled', 'island', 'of', 'Taiwan')
# ('island', 'of', 'Taiwan', '.')
# ('of', 'Taiwan', '.', 'Analysts')
# ('Taiwan', '.', 'Analysts', 'say')
# ('.', 'Analysts', 'say', 'all')
# ('Analysts', 'say', 'all', 'these')
# ('say', 'all', 'these', 'things')
# ('all', 'these', 'things', 'would')
# ('these', 'things', 'would', 'have')
# ('things', 'would', 'have', 'likely')
# ('would', 'have', 'likely', 'happened')
# ('have', 'likely', 'happened', 'without')
# ('likely', 'happened', 'without', 'the')
# ('happened', 'without', 'the', 'war')
# ('without', 'the', 'war', 'in')
# ('the', 'war', 'in', 'Ukraine')
# ('war', 'in', 'Ukraine', ',')
# ('in', 'Ukraine', ',', 'but')
# ('Ukraine', ',', 'but', 'the')
# (',', 'but', 'the', 'war')
# ('but', 'the', 'war', ',')
# ('the', 'war', ',', 'and')
# ('war', ',', 'and', 'China')
# (',', 'and', 'China', '’')
# ('and', 'China', '’', 's')
# ('China', '’', 's', 'backing')
# ('’', 's', 'backing', 'of')
# ('s', 'backing', 'of', 'Russia')
# ('backing', 'of', 'Russia', ',')
# ('of', 'Russia', ',', 'has')
# ('Russia', ',', 'has', 'helped')
# (',', 'has', 'helped', 'grease')
# ('has', 'helped', 'grease', 'the')
# ('helped', 'grease', 'the', 'skids')
# ('grease', 'the', 'skids', 'to')
# ('the', 'skids', 'to', 'get')
# ('skids', 'to', 'get', 'these')
# ('to', 'get', 'these', 'projects')
# ('get', 'these', 'projects', 'done')
# ('these', 'projects', 'done', '.')
# ('projects', 'done', '.', 'Take')
# ('done', '.', 'Take', 'the')
# ('.', 'Take', 'the', 'situation')
# ('Take', 'the', 'situation', 'of')
# ('the', 'situation', 'of', 'Japan')
# ('situation', 'of', 'Japan', ',')
# ('of', 'Japan', ',', 'a')
# ('Japan', ',', 'a', 'country')
# (',', 'a', 'country', 'limited')
# ('a', 'country', 'limited', 'in')
# ('country', 'limited', 'in', 'its')
# ('limited', 'in', 'its', 'post-World')
# ('in', 'its', 'post-World', 'War')
# ('its', 'post-World', 'War', 'II')
# ('post-World', 'War', 'II', 'constitution')
# ('War', 'II', 'constitution', 'to')
# ('II', 'constitution', 'to', '“')
# ('constitution', 'to', '“', 'self-defense')
# ('to', '“', 'self-defense', '”')
# ('“', 'self-defense', '”', 'forces')
# ('self-defense', '”', 'forces', '.')
# ('”', 'forces', '.', 'Now')
# ('forces', '.', 'Now', 'it')
# ('.', 'Now', 'it', '’')
# ('Now', 'it', '’', 's')
# ('it', '’', 's', 'going')
# ('’', 's', 'going', 'to')
# ('s', 'going', 'to', 'buy')
# ('going', 'to', 'buy', 'long-range')
# ('to', 'buy', 'long-range', 'Tomahawk')
# ('buy', 'long-range', 'Tomahawk', 'cruise')
# ('long-range', 'Tomahawk', 'cruise', 'missiles')
# ('Tomahawk', 'cruise', 'missiles', 'from')
# ('cruise', 'missiles', 'from', 'the')
# ('missiles', 'from', 'the', 'US')
# ('from', 'the', 'US', ',')
# ('the', 'US', ',', 'weapons')
# ('US', ',', 'weapons', 'that')
# (',', 'weapons', 'that', 'could')
# ('weapons', 'that', 'could', 'strike')
# ('that', 'could', 'strike', 'well')
# ('could', 'strike', 'well', 'inside')
# ('strike', 'well', 'inside', 'China')
# ('well', 'inside', 'China', '.')
# ('inside', 'China', '.', '“')
# ('China', '.', '“', 'I')
# ('.', '“', 'I', 'myself')
# ('“', 'I', 'myself', 'have')
# ('I', 'myself', 'have', 'a')
# ('myself', 'have', 'a', 'strong')
# ('have', 'a', 'strong', 'sense')
# ('a', 'strong', 'sense', 'of')
# ('strong', 'sense', 'of', 'urgency')
# ('sense', 'of', 'urgency', 'that')
# ('of', 'urgency', 'that', 'Ukraine')
# ('urgency', 'that', 'Ukraine', 'today')
# ('that', 'Ukraine', 'today', 'may')
# ('Ukraine', 'today', 'may', 'be')
# ('today', 'may', 'be', 'East')
# ('may', 'be', 'East', 'Asia')
# ('be', 'East', 'Asia', 'tomorrow')
# ('East', 'Asia', 'tomorrow', ',')
# ('Asia', 'tomorrow', ',', '”')
# ('tomorrow', ',', '”', 'Japanese')
# (',', '”', 'Japanese', 'Prime')
# ('”', 'Japanese', 'Prime', 'Minister')
# ('Japanese', 'Prime', 'Minister', 'Fumio')
# ('Prime', 'Minister', 'Fumio', 'Kishida')
# ('Minister', 'Fumio', 'Kishida', 'told')
# ('Fumio', 'Kishida', 'told', 'a')
# ('Kishida', 'told', 'a', 'major')
# ('told', 'a', 'major', 'defense')
# ('a', 'major', 'defense', 'conference')
# ('major', 'defense', 'conference', 'in')
# ('defense', 'conference', 'in', 'Singapore')
# ('conference', 'in', 'Singapore', 'last')
# ('in', 'Singapore', 'last', 'summer')
# ('Singapore', 'last', 'summer', '.')
# ('last', 'summer', '.', 'In')
# ('summer', '.', 'In', 'December')
# ('.', 'In', 'December', ',')
# ('In', 'December', ',', 'Kishida')
# ('December', ',', 'Kishida', 'followed')
# (',', 'Kishida', 'followed', 'that')
# ('Kishida', 'followed', 'that', 'up')
# ('followed', 'that', 'up', 'with')
# ('that', 'up', 'with', 'a')
# ('up', 'with', 'a', 'plan')
# ('with', 'a', 'plan', 'to')
# ('a', 'plan', 'to', 'double')
# ('plan', 'to', 'double', 'Tokyo')
# ('to', 'double', 'Tokyo', '’')
# ('double', 'Tokyo', '’', 's')
# ('Tokyo', '’', 's', 'defense')
# ('’', 's', 'defense', 'spending')
# ('s', 'defense', 'spending', 'while')
# ('defense', 'spending', 'while', 'acquiring')
# ('spending', 'while', 'acquiring', 'weapons')
# ('while', 'acquiring', 'weapons', 'with')
# ('acquiring', 'weapons', 'with', 'ranges')
# ('weapons', 'with', 'ranges', 'well')
# ('with', 'ranges', 'well', 'outside')
# ('ranges', 'well', 'outside', 'Japanese')
# ('well', 'outside', 'Japanese', 'territory')
# ('outside', 'Japanese', 'territory', '.')

# %% [markdown]
# ### Quiz-5 : 執行到現在，有沒有哪裡覺得怪怪的？申論看看？

# %%
# 哪裡怪怪的？

# %%
from nltk.tokenize import sent_tokenize

sent_result = sent_tokenize(Content_CNN)

# check result
print(sent_result)
# Out:
# ['A year after Russia invaded Ukraine, Xi Jinping’s backing of Vladimir Putin has opened the door for the United States and partners in the Pacific to shore up sometimes frayed relationships to the detriment of Beijing.', 'In the past few months alone, Japan has pledged to double defense spending and acquire long-range weapons from the US; South Korea has acknowledged that stability in the Taiwan Strait is essential to its security; the Philippines has announced new US base access rights and is talking about joint patrols of the South China Sea with Australia, Japan and the United States.', 'Those might be the biggest initiatives, but they are far from the only events that have left China increasingly isolated in its own backyard as it refuses to condemn the invasion of a sovereign country by its partner in Moscow while keeping military pressure on the self-ruled island of Taiwan.', 'Analysts say all these things would have likely happened without the war in Ukraine, but the war, and China’s backing of Russia, has helped grease the skids to get these projects done.', 'Take the situation of Japan, a country limited in its post-World War II constitution to “self-defense” forces.', 'Now it’s going to buy long-range Tomahawk cruise missiles from the US, weapons that could strike well inside China.', '“I myself have a strong sense of urgency that Ukraine today may be East Asia tomorrow,” Japanese Prime Minister Fumio Kishida told a major defense conference in Singapore last summer.', 'In December, Kishida followed that up with a plan to double Tokyo’s defense spending while acquiring weapons with ranges well outside Japanese territory.']
