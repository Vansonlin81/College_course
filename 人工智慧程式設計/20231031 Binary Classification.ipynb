# %% [markdown]
# # 環境準備

# %% [markdown]
# ## 安裝 HappyML 函式庫

# %%
# Install HappyML
import os

if not os.path.isdir("HappyML"):
  os.system("git clone https://github.com/cnchi/HappyML.git")

# %% [markdown]
# ## 下載資料集

# %%
# Upload Dataset
Dataset_File = "Mushrooms.csv"

if not os.path.isfile(Dataset_File):
  os.system("wget https://raw.githubusercontent.com/cnchi/datasets/master/" + Dataset_File)

# %% [markdown]
# # 資料集前處理

# %% [markdown]
# ## 載入資料集

# %%
import HappyML.preprocessor as pp

# Load Data
dataset = pp.dataset(file="Mushrooms.csv")

# %% [markdown]
# ## 切分自變數與應變數

# %%
# Decomposition
X, Y = pp.decomposition(dataset, x_columns=[i for i in range(1, 23)], y_columns=[0])

# %% [markdown]
# ## 處理缺失資料

# %%
X = pp.missing_data(X, strategy="mean")

# %% [markdown]
# ## 類別資料數位化

# %%
# Categorical Data
X = pp.onehot_encoder(X, columns=[i for i in range(22)], remove_trap=True)
Y = pp.label_encoder(Y)

# %% [markdown]
# ## 切分訓練集、測試集

# %%
# Split Training / Testing Set
X_train, X_test, Y_train, Y_test = pp.split_train_test(x_ary=X, y_ary=Y)

# %% [markdown]
# ## 特徵縮放

# %%
# Feature Scaling
X_train, X_test = pp.feature_scaling(fit_ary=X_train, transform_arys=(X_train, X_test))

# %% [markdown]
# # 模型建置

# %%
#from tensorflow.keras.models import Sequential
#from tensorflow.keras.layers import Dense
#
## Initialize the whole Neural Networks
#model = Sequential()
#
## Add the Input & First Hidden Layer
#model.add(Dense(input_dim=X_train.shape[1], units=45, kernel_initializer="glorot_normal", activation="relu"))
#
## Add the Second Hidden Layer
#model.add(Dense(units=23, kernel_initializer="glorot_normal", activation="relu"))
#
## Add the Output Layer
#model.add(Dense(units=1, kernel_initializer="glorot_normal", activation="sigmoid"))
#
## Compile the whole Neural Networks
#model.compile(optimizer="adam", loss="binary_crossentropy", metrics=["acc"])

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# Add Layers with .add() function
model = Sequential()

# Using Formula #2, Instance=20640, alpha=5
model.add(Dense(input_dim=X_train.shape[1], units=45, kernel_initializer="glorot_normal", activation="relu"))
model.add(Dense(units=23, kernel_initializer="glorot_normal", activation="relu"))
model.add(Dense(units=1, kernel_initializer="glorot_normal", activation="sigmoid"))

# %%
print(model.summary())
print('-'*80)
print(model.inputs)
print('-'*80)
print(model.outputs)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 45)                4320
#
#  dense_1 (Dense)             (None, 23)                1058
#
#  dense_2 (Dense)             (None, 1)                 24
#
# =================================================================
# Total params: 5402 (21.10 KB)
# Trainable params: 5402 (21.10 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# --------------------------------------------------------------------------------
# [<KerasTensor: shape=(None, 95) dtype=float32 (created by layer 'dense_input')>]
# --------------------------------------------------------------------------------
# [<KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'dense_2')>]

# %%
import HappyML.neural_networks as nn

# Model Compiling
model = nn.create_seq_model(nodes=[X_train.shape[1], 45, 23, 1], output_activation="sigmoid", loss_name="binary_crossentropy")

# %% [markdown]
# ## 神經網路編譯

# %%
# Compile the whole Neural Networks
model.compile(optimizer="adam", loss="binary_crossentropy", metrics=["acc"])

# %% [markdown]
# # 模型校正

# %%
# Load the TensorBoard notebook extension
# %load_ext tensorboard

# Create TensorBoard log directory
import os
from datetime import datetime
from tensorflow.keras.callbacks import TensorBoard

logdir = os.path.join("logs", datetime.now().strftime("%Y%m%d-%H%M%S"))
tensorboard_callback = TensorBoard(logdir, histogram_freq=1)

# %%
# Start the TensorBoard
# %tensorboard --logdir logs

# %%
# Model Training
epochs_metrics = model.fit(x=X_train, y=Y_train, validation_split=0.2, batch_size=10, epochs=10, callbacks=[tensorboard_callback])
# Out:
# Epoch 1/10
# 488/488 [==============================] - 3s 3ms/step - loss: 0.0884 - acc: 0.9748 - val_loss: 0.0109 - val_acc: 0.9975
# Epoch 2/10
# 488/488 [==============================] - 1s 2ms/step - loss: 0.0031 - acc: 0.9998 - val_loss: 0.0064 - val_acc: 0.9984
# Epoch 3/10
# 488/488 [==============================] - 1s 2ms/step - loss: 0.0017 - acc: 0.9998 - val_loss: 0.0028 - val_acc: 0.9984
# Epoch 4/10
# 488/488 [==============================] - 1s 2ms/step - loss: 5.0543e-04 - acc: 0.9998 - val_loss: 9.2080e-04 - val_acc: 0.9992
# Epoch 5/10
# 488/488 [==============================] - 1s 2ms/step - loss: 1.2808e-04 - acc: 1.0000 - val_loss: 0.0012 - val_acc: 0.9992
# Epoch 6/10
# 488/488 [==============================] - 1s 2ms/step - loss: 7.4042e-05 - acc: 1.0000 - val_loss: 0.0011 - val_acc: 0.9992
# Epoch 7/10
# 488/488 [==============================] - 1s 2ms/step - loss: 4.7056e-05 - acc: 1.0000 - val_loss: 0.0010 - val_acc: 0.9992
# Epoch 8/10
# 488/488 [==============================] - 1s 2ms/step - loss: 3.1221e-05 - acc: 1.0000 - val_loss: 0.0011 - val_acc: 0.9992
# Epoch 9/10
# 488/488 [==============================] - 1s 2ms/step - loss: 2.1876e-05 - acc: 1.0000 - val_loss: 0.0011 - val_acc: 0.9992
# Epoch 10/10
# 488/488 [==============================] - 1s 2ms/step - loss: 1.5761e-05 - acc: 1.0000 - val_loss: 0.0011 - val_acc: 0.9992

# %% [markdown]
# # 模型訓練

# %%
# Model Training
epochs_metrics = model.fit(x=X_train, y=Y_train, validation_split=0.2, batch_size=10, epochs=20)
# Out:
# Epoch 1/20
# 488/488 [==============================] - 1s 2ms/step - loss: 1.0998e-05 - acc: 1.0000 - val_loss: 0.0012 - val_acc: 0.9992
# Epoch 2/20
# 488/488 [==============================] - 1s 2ms/step - loss: 8.2084e-06 - acc: 1.0000 - val_loss: 0.0011 - val_acc: 0.9992
# Epoch 3/20
# 488/488 [==============================] - 1s 2ms/step - loss: 5.8486e-06 - acc: 1.0000 - val_loss: 0.0011 - val_acc: 0.9992
# Epoch 4/20
# 488/488 [==============================] - 1s 2ms/step - loss: 4.3402e-06 - acc: 1.0000 - val_loss: 0.0011 - val_acc: 0.9992
# Epoch 5/20
# 488/488 [==============================] - 1s 2ms/step - loss: 3.1670e-06 - acc: 1.0000 - val_loss: 0.0011 - val_acc: 0.9992
# Epoch 6/20
# 488/488 [==============================] - 1s 2ms/step - loss: 2.4255e-06 - acc: 1.0000 - val_loss: 9.9616e-04 - val_acc: 0.9992
# Epoch 7/20
# 488/488 [==============================] - 1s 2ms/step - loss: 1.7825e-06 - acc: 1.0000 - val_loss: 9.7858e-04 - val_acc: 0.9992
# Epoch 8/20
# 488/488 [==============================] - 1s 2ms/step - loss: 1.3346e-06 - acc: 1.0000 - val_loss: 9.8117e-04 - val_acc: 0.9992
# Epoch 9/20
# 488/488 [==============================] - 1s 2ms/step - loss: 1.0090e-06 - acc: 1.0000 - val_loss: 8.6430e-04 - val_acc: 0.9992
# Epoch 10/20
# 488/488 [==============================] - 1s 2ms/step - loss: 7.4820e-07 - acc: 1.0000 - val_loss: 8.6396e-04 - val_acc: 0.9992
# Epoch 11/20
# 488/488 [==============================] - 1s 2ms/step - loss: 5.6603e-07 - acc: 1.0000 - val_loss: 7.6288e-04 - val_acc: 0.9992
# Epoch 12/20
# 488/488 [==============================] - 1s 2ms/step - loss: 4.2266e-07 - acc: 1.0000 - val_loss: 8.0913e-04 - val_acc: 0.9992
# Epoch 13/20
# 488/488 [==============================] - 1s 2ms/step - loss: 3.1876e-07 - acc: 1.0000 - val_loss: 7.7173e-04 - val_acc: 0.9992
# Epoch 14/20
# 488/488 [==============================] - 1s 2ms/step - loss: 2.3835e-07 - acc: 1.0000 - val_loss: 7.9951e-04 - val_acc: 0.9992
# Epoch 15/20
# 488/488 [==============================] - 1s 1ms/step - loss: 1.8463e-07 - acc: 1.0000 - val_loss: 7.6349e-04 - val_acc: 0.9992
# Epoch 16/20
# 488/488 [==============================] - 1s 2ms/step - loss: 1.4114e-07 - acc: 1.0000 - val_loss: 6.0692e-04 - val_acc: 0.9992
# Epoch 17/20
# 488/488 [==============================] - 1s 2ms/step - loss: 1.0392e-07 - acc: 1.0000 - val_loss: 5.9252e-04 - val_acc: 0.9992
# Epoch 18/20
# 488/488 [==============================] - 1s 2ms/step - loss: 7.7760e-08 - acc: 1.0000 - val_loss: 6.1053e-04 - val_acc: 0.9992
# Epoch 19/20
# 488/488 [==============================] - 1s 2ms/step - loss: 6.0594e-08 - acc: 1.0000 - val_loss: 5.3991e-04 - val_acc: 1.0000
# Epoch 20/20
# 488/488 [==============================] - 1s 2ms/step - loss: 4.5939e-08 - acc: 1.0000 - val_loss: 4.9385e-04 - val_acc: 1.0000

# %% [markdown]
# # 預測答案

# %%
# Predict
import pandas as pd
Y_pred = model.predict(x=X_test).astype(int)
Y_pred = pd.DataFrame(Y_pred, index=Y_test.index, columns=Y_test.columns)

# Show the Predict Result
df = pd.concat([Y_test, Y_pred], axis=1)
print(df)
# Out:
# 64/64 [==============================] - 0s 926us/step
#       class  class
# 6751      1      1
# 277       0      0
# 5322      1      0
# 3238      0      0
# 694       1      1
# ...     ...    ...
# 3502      0      0
# 3501      0      0
# 7036      0      0
# 4401      1      1
# 2106      0      0
#
# [2031 rows x 2 columns]

# %% [markdown]
# # 模型評估

# %%
test_loss, test_acc = model.evaluate(X_test, Y_test)
print("Loss of Testing Set:", test_loss)
print("Accuracy of Testing Set:", test_acc)
# Out:
# 64/64 [==============================] - 0s 1ms/step - loss: 2.1934e-07 - acc: 1.0000
# Loss of Testing Set: 2.1934467042683536e-07
# Accuracy of Testing Set: 1.0
